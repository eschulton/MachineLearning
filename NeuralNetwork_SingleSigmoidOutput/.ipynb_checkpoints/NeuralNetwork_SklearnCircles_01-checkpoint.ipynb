# %%
import sklearn.datasets
import sklearn.model_selection
import matplotlib.pyplot as plt
import numpy as np
import neuralnet as nn

# %%
X, y = sklearn.datasets.make_circles(n_samples=1000)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.3)

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis')

# %%
X_train = X_train.T
X_test = X_test.T
y_train = y_train.T.reshape(1, -1)
y_test = y_test.T.reshape(1, -1)

# %%
model = nn.Network(2)
model.add_layer(4, activation_name="lrelu")
model.add_layer(1, activation_name="sigmoid")
model.train(X_train, y_train)
# Out:
# iteration = 1 ; cost = 0.7120376426445436 ; accuracy = 48.857142857142854%
# iteration = 101 ; cost = 0.6406490419405558 ; accuracy = 64.0%
# iteration = 201 ; cost = 0.49884382839693525 ; accuracy = 84.0%
# iteration = 301 ; cost = 0.3616660330683468 ; accuracy = 99.42857142857143%
# iteration = 401 ; cost = 0.2654661685212655 ; accuracy = 95.71428571428572%
# iteration = 501 ; cost = 0.13180741358995435 ; accuracy = 100.0%
# iteration = 601 ; cost = 0.09562607798152714 ; accuracy = 100.0%
# iteration = 701 ; cost = 0.07650931890692904 ; accuracy = 100.0%
# iteration = 801 ; cost = 0.06386266770449098 ; accuracy = 100.0%
# iteration = 901 ; cost = 0.05483233649347046 ; accuracy = 100.0%

# %%
model.test(X_test, y_test)
# Out:
# cost = 0.052025036011629965 ; accuracy = 100.0%

# %%
plt.plot(model.cost_history)
